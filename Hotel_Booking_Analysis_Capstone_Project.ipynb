# %% [markdown]
# <a href="https://colab.research.google.com/github/ajitkumarpatel1/HOTEL_BOOKING_ANALYSIS/blob/main/Hotel_Booking_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions!
#
# ## <b>This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data. </b>
#
# ## <b> Explore and analyze the data to discover important factors that govern the bookings. </b>

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ###<b>Exploratory Data (EDA) is an approach in analyzing data sets to summarize their main characteristics using statistical graphics and other data visualization methods. This helps in getting a better understanding of the data, discover patterns,to spot anomalies,to test hypothesis and to check assumptions with the help of summary statistics and graphical representations.</b>
#
#
#
# <b>Outline of the Project:</b>
# -------------------------------
#
# * Installing and importing the required libraries
# * Data preparation and cleaning
# * Exploratory analysis and visualization of columns
# * Asking and answering questions about the data
# * Summary
# * References and ideas for future work

# %% [markdown]
# -------------------------------------
#
# ---
#
#
#
# ---

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# <b>Now its time to know somithing about hotel data
#
#
#
# ##<b>1. Installing and importing the required libraries

# %%
# importing all the required library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# mounting the google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##<b>Load data into the dataframe:

# %%
# importing the hotel data csv file
data = pd.read_csv('/content/drive/MyDrive/ALMABATTER/Hotel Booking Analysis - Ajit Kumar Patel/Hotel Bookings.csv')

# %%
# to get the 1st 5 row (default vale) and all columns of our dataset
data.head(3)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# 1                        0                     0       2  ...    No Deposit
# 2                        0                     1       1  ...    No Deposit
#
#    agent company days_in_waiting_list customer_type   adr  \
# 0    NaN     NaN                    0     Transient   0.0
# ...

# %% [markdown]
# # <b> Below is a description of our Hotel Booking Analysis data :
#
# ---
#
#
#
# ###<b>The dataset includes a wide range of bocking information with distinguish between city and a resort hotels. Here is a detailed list of the table topics with a short explnation of what each column means and the type of information it is storing:
#
# * hotel: hotel type(H1 = Resort Hotel or H2 = City Hotel)
# * is_canceled: Value indicating if the booking was canceled (1) or not (0)
# * lead_time: Number of days that elapsed between the entering date of the booking and the arrival date
# * arrival_date_year: Year of arrival date
# * arrival_date_month: Month of arrival date
# * arrival_date_week_number: Week number of year for arrival date
# * arrival_date_day_of_month: Day of arrival date
# * stays_in_weekend_nights: Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel
# * stays_in_week_nights: Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel
# * adults: Number of adults (an adult is a person older than 19 years of age )
# * children: Number of children(whereas the word 'child' refers to any child from three months to 12 years of age.)
# * babies: Number of babies ( The word 'baby' means any child from birth to age 4,)
# * meal: Type of meal booked. Categories are presented in standard hospitality
#
#  <b>meal packages</b>:
#
#
#      1.   Undefined/SC - no meal package;
#      2.   BB - Bed & Breakfast;
#      3.   HB - Half board (breakfast and one other meal – usually dinner);
#      4.   FB - Full board (breakfast, lunch and dinner).
#  -
#
# * country: Country of origin.
# * market_segment: Market segment designation. In categories, the term
#        “TA”            - “Travel Agents” (A travel agent will help you arrange
#                          transportation, find lodgings, and suggest an
#                          itinerary)
#         “TO”           - “Tour Operators”.(A tour operator will arrange your
#                         transportation, lodgings, food, entertainment, and
#                         itinerary. )
#         'Direct'       -"direct book by costomour"
#         'Corporate'    -"Helping business travelers find the best stays
#                         by accessing an unrivaled inventory of competitive
#                         hotel deals across any location"
#         'Online TA'     -"online travel agent"
#         'Offline TA/TO' - 'offline travel agent, offline tour operator'
#         'Complementary' -A Complementary good is a product or
#                          service that adds value to another
#         'Groups'        - 'huge mass'
#         'Undefined'     -
#         'Aviation'      -An Aviation Hospitality professional is someone who
#                          works at airlines, airports, or other businesses
#                          within the aviation or aerospace industry, such as
#                          aircraft manufacturers where they take care of
#                          the needs of the consumer
# * distribution_channel: Booking distribution channel. The term “TA” means “Travel Agents” and “TO” means “Tour Operators”.
# * is_repeated_guest: Value indicating if the booking name was from a repeated guest (1) or not (0)
# * previous_cancellations: Number of previous bookings that were cancelled by the customer prior to the current booking
# * previous_bookings_not_canceled: Number of previous bookings not cancelled by the customer prior to the current booking.
# * reserved_room_type: Code of room type reserved. Code is presented instead of designation for anonymity reasons.
# * assigned_room_type: Code for the type of room assigned to the booking. Sometimes the assigned room type differs from the reserved room type due to hotel operation reasons (e.g. overbooking) or by customer request. Code is presented instead of designation for anonymity reasons.
# * booking_changes: Number of changes/amendments made to the booking from the moment the booking was entered on the PMS until the moment of check-in or cancellation.
# * deposit_type: Indication on if the customer made a deposit to guarantee the booking. This variable can assume three categories:
#     No Deposit – no deposit was made;
#     Non Refund – a deposit was made in the value of the total stay cost;
#     Refundable – a deposit was made with a value under the total cost of stay.
# * agent: ID of the travel agency that made the booking
# * company: ID of the company/entity that made the booking or responsible for paying the booking. ID is presented instead of designation for anonymity reasons.
# * days_in_waiting_list: Number of days the booking was in the waiting list before it was confirmed to the customer.
# * customer_type: Type of booking, assuming one of four categories: Contract - when the booking has an allotment or other type of contract associated to it; * Group – when the booking is associated to a group; Transient – when the booking is not part of a group or contract, and is not associated to other transient booking; Transient-party – when the booking is transient, but is associated to at least other transient booking.
# * adr: Average Daily Rate as defined by dividing the sum of all lodging transactions by the total number of staying nights.
# * required_car_parking_spaces: Number of car parking spaces required by the customer
# * total_of_special_requests: Number of special requests made by the customer (e.g. twin bed or high floor)
# * reservation_status: Reservation last status, assuming one of three categories: Canceled – booking was canceled by the customer; Check-Out – customer has * checked in but already departed; No-Show – customer did not check-in and did inform the hotel of the reason why.
# * reservation_status_date: Date at which the last status was set. This variable can be used in conjunction with the ReservationStatus to understand when was the booking canceled or when did the customer checked-out of the hotel.

# %% [markdown]
# <b>OVERVIEW</b>
#
# Dataset statistics
#
# * Number of rows:    119390
# * Number of columns:    32
# * Missing values:    129425
# * Missing values (%):    3.4%

# %% [markdown]
# <b>Data Preprocessing

# %%
## First copy the dataset, so our original dataset remains unchanged
df = data.copy()

# %%
# sample is a way to see the data from data set randomly
df.sample(24)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 105837    City Hotel            0         12               2017
# 82713     City Hotel            0         23               2016
# 49201     City Hotel            1         69               2016
# 32859   Resort Hotel            0         10               2017
# 91647     City Hotel            0         19               2016
# 18962   Resort Hotel            0         17               2015
# 25832   Resort Hotel            0        180               2016
# 46377     City Hotel            1        148               2015
# 51492     City Hotel            1        211               2016
# 11937   Resort Hotel            1        219               2017
# 116968    City Hotel            0        127               2017
# 79748     City Hotel            0          5               2015
# 43487     City Hotel            0         95               2015
# 95038     City Hotel            0        117               2016
# ...

# %% [markdown]
# ###<b>Number of rows and columns

# %%
# this helps us to know how many entry(row) and features(column) are present in our data set
df.shape
# Out:
# (119390, 32)

# %% [markdown]
# By the first glance at the dataset, we can see that the table containse 32 columns of booking information over 119390 hotels.
# By using the .shape() method we can get the same kind of information without the table:

# %% [markdown]
# ###<b>Column names
#
# *By* using the <b>(columns method)</b> we can get a list of all the featuers provided in the dataset, as follow:

# %%
# # using a loop to print all the columns name
# for i in df :
#   print (i)

# it have also a inbult funtion: 
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# To know how many uinque items are present in our data set:
for i in df:
    print(f'the {i} contains  {df[i].nunique()} {df[i].dtype} type unique items')
# Out:
# the hotel contains  2 object type unique items
# the is_canceled contains  2 int64 type unique items
# the lead_time contains  479 int64 type unique items
# the arrival_date_year contains  3 int64 type unique items
# the arrival_date_month contains  12 object type unique items
# the arrival_date_week_number contains  53 int64 type unique items
# the arrival_date_day_of_month contains  31 int64 type unique items
# the stays_in_weekend_nights contains  17 int64 type unique items
# the stays_in_week_nights contains  35 int64 type unique items
# the adults contains  14 int64 type unique items
# the children contains  5 float64 type unique items
# the babies contains  5 int64 type unique items
# the meal contains  5 object type unique items
# the country contains  177 object type unique items
# the market_segment contains  8 object type unique items
# the distribution_channel contains  5 object type unique items
# the is_repeated_guest contains  2 int64 type unique items
# ...

# %% [markdown]
# ###<b>Column information & Data Types
#
# Now lets take a high-level look over the data using the .info() method:

# %%
# getting the all information about the data set
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# ###<b>Numerical Data descripetion
#
# describe() method that can give us more statistic details on all the table's features

# %%
# it's allow us to know the measures of central tendency about the neumerical data data present in our DataSet
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ###<b>Categorical Data Description

# %%
# Describe the catagorical features 
df.describe(include = "object")
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status reservation_status_date
# count        119390        119390             119390                  119390
# unique            3             4                  3                     926
# ...

# %% [markdown]
# ###<b>Finding Missing Values
#
# Check if our data contains any missing values
#
# * find more missing values in the dataset using the .isna() method

# %%
# Check if our data contains any missing values
#null = df.isna().sum().sort_values()/len(df)
null = df.isna().sum().sort_values(ascending=False)
null
# Out:
# company                           112593
# agent                              16340
# country                              488
# children                               4
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# hotel                                  0
# previous_cancellations                 0
# days_in_waiting_list                   0
# customer_type                          0
# adr                                    0
# required_car_parking_spaces            0
# total_of_special_requests              0
# reservation_status                     0
# previous_bookings_not_canceled         0
# is_repeated_guest                      0
# is_canceled                            0
# distribution_channel                   0
# market_segment                         0
# meal                                   0
# babies                                 0
# ...

# %%
# anathor approach to do this upper task (to find out null value)
for i in df :
  if df[i].isna().sum()!=0:
    print(i,"is having ",df[i].isna().sum(),"null values")
# Out:
# children is having  4 null values
# country is having  488 null values
# agent is having  16340 null values
# company is having  112593 null values

# %% [markdown]
# ###<b> Data Cleaning & Treating Missing Value:

# %%
# now we dropping the unnecessar and the most nulabel column from our data set 
# hear company is drop because the null valu is maximum and 
# arrival_date_week_number is drop because this is not that much important to our dataset
df.drop(["company","arrival_date_week_number"] , inplace = True , axis = 1)

# %%
# Now its the time to fill the missing value as for the as thair needs
# country = .mode() ---- (catagorical value)
# children = .median() ---- (floting value)
# agent = .median() ----- (floting value)
df['country'].fillna(df['country'].mode()[0],inplace = True)
df['children'].fillna(df['children'].median(),inplace = True)
df['agent'].fillna(df['agent'].median(),inplace = True)

# %%
# checking the missing vallu is fell or not
df.isna().sum().sort_values(ascending = False)/len(df)
# Out:
# hotel                             0.0
# is_canceled                       0.0
# reservation_status                0.0
# total_of_special_requests         0.0
# required_car_parking_spaces       0.0
# adr                               0.0
# customer_type                     0.0
# days_in_waiting_list              0.0
# agent                             0.0
# deposit_type                      0.0
# booking_changes                   0.0
# assigned_room_type                0.0
# reserved_room_type                0.0
# previous_bookings_not_canceled    0.0
# previous_cancellations            0.0
# is_repeated_guest                 0.0
# distribution_channel              0.0
# market_segment                    0.0
# country                           0.0
# meal                              0.0
# babies                            0.0
# children                          0.0
# adults                            0.0
# stays_in_week_nights              0.0
# stays_in_weekend_nights           0.0
# ...

# %%
# casual check
# Here we can see that the arrival_date_year ,arrival_date_month , arival_date_day_of_year
# are separated we try to make a arrival date column
df['arrival_date'] = df['arrival_date_month'].astype(str) + " " + df['arrival_date_day_of_month'].astype(str)+ " "+ df['arrival_date_year'].astype(str)
df['arrival_date'] = pd.to_datetime(df['arrival_date'])

# %%
# now we merge all the addational guest like: adults and children to know how many addational gest are present
df['addational_guests'] =  df['children'] +df['babies']

# %%
# checking the shape of dataset
df.shape
# Out:
# (119390, 32)

# %% [markdown]
# ###<b> Converting Datatype
#
# Let’s check the datatype of each column in our dataset

# %%
## convert datatype of these columns from float to integer
df[['addational_guests', 'agent','adr']] = df[['addational_guests', 'agent','adr']].astype('int64')

# %%
# Let’s check the datatype of each column in our dataset.
df.dtypes
# Out:
# hotel                                     object
# is_canceled                                int64
# lead_time                                  int64
# arrival_date_year                          int64
# arrival_date_month                        object
# arrival_date_day_of_month                  int64
# stays_in_weekend_nights                    int64
# stays_in_week_nights                       int64
# adults                                     int64
# children                                 float64
# babies                                     int64
# meal                                      object
# country                                   object
# market_segment                            object
# distribution_channel                      object
# is_repeated_guest                          int64
# previous_cancellations                     int64
# previous_bookings_not_canceled             int64
# reserved_room_type                        object
# ...

# %% [markdown]
# We can see different data types for different's columns.
#
# There are some columns like 'addational_guests', 'agent','adr' that are float type and i convert that in int type for batter calculation.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_day_of_month       119390 non-null  int64
#  6   stays_in_weekend_nights         119390 non-null  int64
#  7   stays_in_week_nights            119390 non-null  int64
#  8   adults                          119390 non-null  int64
#  9   children                        119390 non-null  float64
#  10  babies                          119390 non-null  int64
#  11  meal                            119390 non-null  object
# ...

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# #<b>(3) Exploratory Data Analysis</b>

# %% [markdown]
# ##<b>Asking and answering questions about the data and try to see the visualisation for batter understanding
#
#
# ###<b>(a)Which accommodation is most preferable by people and what is the cancelation rate

# %%
# to find out the types of hottel
types_of_hotel = df['hotel'].unique()
print(f'the types of hotels are : {types_of_hotel}')

# to know how many resort hotel and city hotels are present

city_hot=[i for i in df["hotel"] if i!="Resort Hotel"]
print(f'the total no of city_hotels are : {len(city_hot)}')

resort_hot=[i for i in df["hotel"] if i=="Resort Hotel"]
print(f'the total no of resort_hotels are : {len(resort_hot)}')

total_hotels = (len(resort_hot))+(len(city_hot))
print(f'the total no of total hotel present : {total_hotels}')
# Out:
# the types of hotels are : ['Resort Hotel' 'City Hotel']
# the total no of city_hotels are : 79330
# the total no of resort_hotels are : 40060
# the total no of total hotel present : 119390

# %%
# The database devided into two types of hotels "city" hotels and "Resort" hotels.
# The following pie chart visually represents the relative share in percentages of each type of hotel

no_of_booking_cancel = df.groupby('hotel')['is_canceled'].value_counts().to_frame()
no_of_booking_cancel.rename(columns= {'is_canceled':'booking status'},inplace = True)
no_of_booking_cancel.head()
# Out:
#                           booking status
# hotel        is_canceled
# City Hotel   0                     46228
#              1                     33102
# Resort Hotel 0                     28938
#              1                     11122

# %%
# Percentage of hotels present in our data set
sns.set_style('whitegrid')
plot = df['hotel'].value_counts().plot.pie(x ='City Hotel', y = 'Resort Hotel' , autopct='%1.1f%%', figsize=(5,5))

# %%
# No of hotels canceled from total booking
from seaborn.categorical import countplot
plt.figure(figsize  = (10,6))
ax = countplot(x = 'hotel' ,data= df , hue = 'is_canceled')
for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x() +0.1, p.get_height()+500))

# %% [markdown]
# ####<b>Observation :</b>Out of all bookings 66.4 % booking are for city hotel and the cancelation rate is also high and 33.6 % bookings are for resort hotel and the cancelation rate is low as compair to city hotel.

# %% [markdown]
# ###<b>(b). What is the total number of booking and cancelation held in per year ?

# %%
#making a group of sellected data from dataframe
booking_per_year = df.groupby('arrival_date')['hotel'].value_counts().to_frame().unstack()
booking_per_year
# Out:
#                   hotel
# hotel        City Hotel Resort Hotel
# arrival_date
# 2015-07-01           79           43
# 2015-07-02           49           44
# 2015-07-03           16           40
# 2015-07-04           38           50
# 2015-07-05            8           45
# ...                 ...          ...
# 2017-08-27          107           67
# 2017-08-28          133           78
# 2017-08-29           90           35
# 2017-08-30           47           42
# 2017-08-31           79           55
#
# [793 rows x 2 columns]

# %%
# plt.figure(figsize = (20,10))
a = booking_per_year.plot()
a.set_title('total years of booking')
plt.ylabel('Total number of booking')
plt.xlabel('year')
# Out:
# Text(0.5, 0, 'year')

# %% [markdown]
# ###<b>* What is the Average daily checking by month wise ?

# %%
df['arrival_day'] = df['arrival_date'].dt.day_name()

# %%
plt.figure(figsize =(6,6))
checkinday = df.groupby(['arrival_day','arrival_date_month']).mean()['adults'].unstack(level = -1)
plt.figure(figsize =(12,10))
sns.heatmap(checkinday,cmap='coolwarm')
plt.title('Average daily checkin by month')
plt.show()

# %% [markdown]
# ####<b>Observation:</B> Most of check in are on weekend friday and saturday counts have the highesr booking.
# * mon,wed and thusday have the lowest booking.

# %% [markdown]
# ###<b>* Cancelation per year wise

# %%
# Cancelation of hotel per year
lead_year = df.groupby('arrival_date_year')['is_canceled'].value_counts().to_frame().unstack()
lead_year
# Out:
#                   is_canceled
# is_canceled                 0      1
# arrival_date_year
# 2015                    13854   8142
# 2016                    36370  20337
# 2017                    24942  15745

# %%
plt.figure(figsize=(8,6))
g = sns.countplot(x = 'arrival_date_year' , data=df ,hue = "is_canceled" )
g.set_title('total years of booking')
plt.ylabel('no of booking')
plt.xlabel('years')
# Out:
# Text(0.5, 0, 'years')

# %% [markdown]
# ####<b>Observation:</B>More than double bookings were made in 2016, compared to the previous year. But the bookings decreased by almost 15% the next year.

# %% [markdown]
# ###<b>(c)In which month the reservation is in peack,lowest and what is the busiest months for hotel and resorts?

# %%
plt.figure(figsize=(15.7,7.27))
g = sns.countplot(data=df,x="arrival_date_month",hue="hotel",order=["January","February","March","April","May","June","July","August","September","October","November","December"],)
g.set_title("Monthly Reservation Count by Hotel Type")
plt.ylabel('moths of booking')
plt.xlabel('years of booking')
# Out:
# Text(0.5, 0, 'years of booking')

# %% [markdown]
# ####Observation:
#
# <b>city and resort hotels</b>
#
# Highest reservation : August
#
# lowest reservations : January
#
# reservation getting peack:March to October
#
# reservation getting down : november to january
#
# *  In case of city hotel, months with high bookings (May, June, September, October) also witnessed more cancellations. Guest numbers for the Resort hotel go down slighty from June to September though variations in bookings and cancellations are less in case of resort hotel. Both hotels have the fewest guests during the winter.

# %% [markdown]
# ###<b>(D) What is the monthly sales of Hotel's every years ?

# %%
monthely_cancel_booking =df.groupby('arrival_date_month')['is_canceled'].sum().sort_values()
monthely_cancel_booking
# Out:
# arrival_date_month
# January      1807
# November     2122
# December     2371
# February     2696
# March        3149
# September    4116
# October      4246
# April        4524
# June         4535
# May          4677
# July         4742
# August       5239
# Name: is_canceled, dtype: int64

# %%
plt.figure(figsize=(15.7,7.27))
g = sns.countplot(data=df,x="arrival_date_month",hue="arrival_date_year",order=["January","February","March","April","May","June","July","August","September","October","November","December"],)

# %% [markdown]
# ####<b>Observation: the booking of accomadation are in incrasing manner from the previous year sales</b>

# %% [markdown]
# ###<b>(E)Maximum number of stays in week nights in each hotel?

# %%
df.groupby(["hotel"])["stays_in_week_nights"].agg(["max"])
# Out:
#               max
# hotel
# City Hotel     41
# Resort Hotel   50

# %%
df.groupby("stays_in_week_nights")['is_canceled'].agg(['count']).iloc[:10]
# Out:
#                       count
# stays_in_week_nights
# 0                      7645
# 1                     30310
# 2                     33684
# 3                     22258
# 4                      9563
# 5                     11077
# 6                      1499
# 7                      1029
# 8                       656
# 9                       231

# %%
sns.countplot(data=df,x ='stays_in_week_nights',hue = 'is_canceled')

# %% [markdown]
# ###<b>(*)Maximum number of stays in weekend nights in each hotel?

# %%
df.groupby(["hotel"])["stays_in_weekend_nights"].agg(["max"])
# Out:
#               max
# hotel
# City Hotel     16
# Resort Hotel   19

# %%
df.groupby("stays_in_weekend_nights")['is_canceled'].agg(['count']).iloc[:10]
# Out:
#                          count
# stays_in_weekend_nights
# 0                        51998
# 1                        30626
# 2                        33308
# 3                         1259
# 4                         1855
# 5                           79
# 6                          153
# 7                           19
# 8                           60
# 9                           11

# %%
sns.countplot(data=df,x ='stays_in_weekend_nights',hue = 'is_canceled')

# %% [markdown]
# ####<b>Observation : Avg cancelation for both weekday and weekend booking is almost same

# %% [markdown]
# ####<b>(F).Maximum how many number of adults book for one room and what may be thair addation guest present?

# %%
a = df.groupby('adults')['addational_guests'].count().reset_index()
a.head(15)
# Out:
#     adults  addational_guests
# 0        0                403
# 1        1              23027
# 2        2              89680
# 3        3               6202
# 4        4                 62
# 5        5                  2
# 6        6                  1
# 7       10                  1
# 8       20                  2
# 9       26                  5
# 10      27                  2
# 11      40                  1
# 12      50                  1
# 13      55                  1

# %%
plt.figure( figsize=(11,6),)
g = sns.countplot(data=df, x="adults",)
g.set_title('Adults booking reservation')
plt.xlabel("set of adults")
plt.ylabel("count of adults")
# Out:
# Text(0, 0.5, 'count of adults')

# %% [markdown]
# ####<b>Observation : The maximum a couples of people are booked the hotel more

# %% [markdown]
# ###<b>What is the Maximum chances for children present with the adults?

# %%
# ploting a count plot to count the children exasistances
plt.figure( figsize=(11,6))
a = sns.countplot(data=df, x="children",)
a.set_title=('Count of Children Per Reservation')
plt.xlabel("Children", fontsize = 14)
plt.ylabel("Count", fontsize = 14)
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ####<b>Observation:
# * The vast majority of reservations have 2 adults followed by 1 adult.
# * the more than 90% of reservation are adults. One child is slightly larger in percentage than two children.

# %% [markdown]
# ###<b>(G) which group of people make more booking canceled ?

# %%
cancelation_by_adult = df.groupby(['hotel','adults'],as_index = False).agg({'is_canceled':"sum"})
cancelation_by_adult.head()
# Out:
#         hotel  adults  is_canceled
# 0  City Hotel       0          107
# 1  City Hotel       1         5454
# 2  City Hotel       2        25756
# 3  City Hotel       3         1778
# 4  City Hotel       4            7

# %%
g = plt.figure( figsize=(11,9),)
g = sns.countplot(data=df, x="adults",hue ='is_canceled')
g.set_title=("cancelation done by adults")
plt.xlabel("no of adults", fontsize = 14)
plt.ylabel("no of cancelation", fontsize = 14)
# Out:
# Text(0, 0.5, 'no of cancelation')

# %%
addational_guests_cancelation = df.groupby('addational_guests')['is_canceled'].value_counts(normalize = True).to_frame().unstack()
addational_guests_cancelation
# Out:
#                   is_canceled
# is_canceled                 0         1
# addational_guests
# 0                    0.627787  0.372213
# 1                    0.692068  0.307932
# 2                    0.588812  0.411188
# 3                    0.729730  0.270270
# 9                    1.000000       NaN
# 10                   0.500000  0.500000

# %% [markdown]
# ###<b>Observation:
# * The vast majority of reservations and cencelation by couple of adults as compair to other.
#
# * The addational guests (children,babys) doesn't effect to the cancelation of hotel.

# %% [markdown]
# ##<b>(H).What are the Adults favorite and least favorite meal?

# %%
# meals_type =df['meal'].value_counts().index
# meals_type
no_of_meals_sale =df['meal'].value_counts()
no_of_meals_sale
# Out:
# BB           92310
# HB           14463
# SC           10650
# Undefined     1169
# FB             798
# Name: meal, dtype: int64

# %%
meals_type =df['meal'].value_counts().index
no_of_meals_sale =df['meal'].value_counts()
plt.rcParams['figure.figsize'] = (10, 5)
plt.bar(meals_type,no_of_meals_sale)
plt.xlabel("Meals type")
plt.ylabel("no of meal sold")
# Out:
# Text(0, 0.5, 'no of meal sold')

# %%
plt.figure(figsize=(10,6))
ml=sns.countplot(data=df,x='meal',hue='hotel')
for m in ml.patches:
  ml.annotate((m.get_height()),(m.get_x() + 0.1,m.get_height()+500),fontsize=10)

# %% [markdown]
# ###<b>meals like by children

# %%
df.iloc[np.where((df["children"] > 0) & (df["meal"] != "Undefined"))]["meal"].agg(["value_counts"])
# Out:
#     value_counts
# BB          7079
# HB          1246
# SC           156
# FB            66

# %% [markdown]
# The categories in the meal column mean:
#
# * BB: Bed & Breakfast
# * HB:: Half board (breakfast and one other * meal – usually dinner)
# * FB: Full board (breakfast, lunch and dinner)
# * Undefined/SC: no meal package
#
# Bed & Breakfast is the most common option among the customers in every hotel type.

# %% [markdown]
# ##<b>(I). From which country the most guests are coming (top 10)?

# %%
top_10_country = list(df.country.value_counts().head(10).index)
no_of_people_10_country= list(df.country.value_counts().head (10))

# %%
a = sns.barplot (top_10_country, no_of_people_10_country)
a.set_title('Travelers country')
plt.ylabel('no of pepole comes from country')
plt.xlabel('Country name')
for p in a.patches:
    a.annotate((p.get_height()), (p.get_x() +0.1, p.get_height()+500))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ###<b>Observation :
# * Most of the foreigner are coming from partugal(prt).

# %% [markdown]
# ###<b> Which country makes the most hotel booking cancelation ?

# %%
#  
ab = df.groupby('country')['is_canceled'].count().head(10).reset_index().sort_values(by='is_canceled',ascending=False)
print(ab)
# Out:
#   country  is_canceled
# 1     AGO          362
# 6     ARG          214
# 5     ARE           51
# 3     ALB           12
# 7     ARM            8
# 4     AND            7
# 0     ABW            2
# 9     ATA            2
# 2     AIA            1
# 8     ASM            1

# %%
country = ab.loc[:,'country']
cancel = ab.loc[:,'is_canceled']
plt.bar(country,cancel)
plt.xlabel("Country name")
plt.ylabel("no of cancelation")
# Out:
# Text(0, 0.5, 'no of cancelation')

# %% [markdown]
# ####<B>Observation:
# * AGO (angola) ,ARG(Argentina) makes the most cancelation hotels.

# %% [markdown]
# ###<b>How many guests arrived year-wise?

# %%
df.groupby(["hotel"])["arrival_date_year"].agg(["value_counts"])
# Out:
#                                 value_counts
# hotel        arrival_date_year
# City Hotel   2016                      38140
#              2017                      27508
#              2015                      13682
# Resort Hotel 2016                      18567
#              2017                      13179
#              2015                       8314

# %%
sns.countplot(x = "hotel", hue = "arrival_date_year", data = df, order = ["City Hotel", "Resort Hotel"]);

# %% [markdown]
# ###<b> Observation:
# * In 2016 most of the guests are booked the hotel.it is shown as fixable in nature.

# %% [markdown]
# ##<b>(J). What is the monthly reservation by market segment ?

# %%
market_segment_cancelation = df.groupby('market_segment')['reservation_status'].value_counts(normalize = True).to_frame().unstack()
market_segment_cancelation
# Out:
#                    reservation_status
# reservation_status           Canceled Check-Out   No-Show
# market_segment
# Aviation                     0.172996  0.780591  0.046414
# Complementary                0.114401  0.869448  0.016151
# Corporate                    0.172993  0.812653  0.014353
# Direct                       0.136602  0.846581  0.016817
# Groups                       0.606885  0.389380  0.003735
# Offline TA/TO                0.333622  0.656840  0.009538
# Online TA                    0.356747  0.632789  0.010464
# Undefined                    1.000000       NaN       NaN

# %%
plt.figure(figsize=(15.7,7.27))
a = sns.countplot(data=df,x="market_segment",hue="reservation_status")
a.set_title("Monthly Reservation Count by Hotel Type")
plt.ylabel('moths of booking')
plt.xlabel('years of booking')
for p in a.patches:
    a.annotate((p.get_height()), (p.get_x() +0.1, p.get_height()+500))

# %% [markdown]
# ###<B>Observation:
# * Online TA ,Groups are makes the most cancellation of hotels as compair to other market segment catagory.
# * Indirect bookings through online and offline travel agents are higher compared to direct bookings and same is the case with group bookings which are also high.

# %% [markdown]
# ###<b>(K)How many guests visited hotel more than once?

# %%
data.groupby(["hotel"])["is_repeated_guest"].agg(["value_counts"])
# Out:
#                                 value_counts
# hotel        is_repeated_guest
# City Hotel   0                         77298
#              1                          2032
# Resort Hotel 0                         38282
#              1                          1778

# %%
sns.countplot(x = "hotel", hue = "is_repeated_guest", data = data)

# %% [markdown]
# ###<b>Observation:
# * In City Hotel 2032 and in Resort Hotel 1778 guests visited more than once which shows the overall service of the hotels was good.

# %% [markdown]
# ###<b>(L) What is the previous reservation_status of hotels per year ?

# %%
data.groupby(["hotel", "arrival_date_year"])["reservation_status"].agg(["value_counts"])
# Out:
#                                                    value_counts
# hotel        arrival_date_year reservation_status
# City Hotel   2015              Check-Out                   7678
#                                Canceled                    5882
#                                No-Show                      122
#              2016              Check-Out                  22733
#                                Canceled                   14852
#                                No-Show                      555
#              2017              Check-Out                  15817
#                                Canceled                   11452
#                                No-Show                      239
# Resort Hotel 2015              Check-Out                   6176
#                                Canceled                    2069
#                                No-Show                       69
#              2016              Check-Out                  13637
# ...

# %%
c = df.groupby("hotel")
for hotel ,hotel_df in c:
  print(hotel)
  # print(hotel_df)
# Out:
# City Hotel
# Resort Hotel

# %% [markdown]
# ### city hotel reservation status

# %%
city_hotel = c.get_group('City Hotel')
city_hotel.sample()
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 87132  City Hotel            0         23               2016
#
#       arrival_date_month  arrival_date_day_of_month  stays_in_weekend_nights  \
# 87132              April                         10                        2
#
#        stays_in_week_nights  adults  children  ...  days_in_waiting_list  \
# 87132                     3       3       0.0  ...                     0
#
#       customer_type  adr required_car_parking_spaces  \
# 87132     Transient  146                           0
#
#       total_of_special_requests  reservation_status  reservation_status_date  \
# 87132                         3           Check-Out               2016-04-15
#
#        arrival_date addational_guests arrival_day
# 87132    2016-04-10                 0      Sunday
#
# [1 rows x 33 columns]

# %%
city_hotel.groupby('arrival_date_year')['reservation_status'].agg(["value_counts"])
# Out:
#                                       value_counts
# arrival_date_year reservation_status
# 2015              Check-Out                   7678
#                   Canceled                    5882
#                   No-Show                      122
# 2016              Check-Out                  22733
#                   Canceled                   14852
#                   No-Show                      555
# 2017              Check-Out                  15817
#                   Canceled                   11452
#                   No-Show                      239

# %%
ml = sns.countplot(data =city_hotel , x= 'arrival_date_year', hue = "reservation_status" )
for m in ml.patches:
  ml.annotate((m.get_height()),(m.get_x() + 0.1,m.get_height()+500),fontsize=10)

# %% [markdown]
# ###<b>Observation:
# * in 2016 the city hotel's 75% booking are cancled. and in 2017 more than 60% bookings are cancled.
# * booking and canclation are high in counts

# %% [markdown]
# Resort Hotel reservation status

# %%
Resort_Hotel = c.get_group('Resort Hotel')
Resort_Hotel.sample()
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 30874  Resort Hotel            0          3               2016
#
#       arrival_date_month  arrival_date_day_of_month  stays_in_weekend_nights  \
# 30874           December                          5                        1
#
#        stays_in_week_nights  adults  children  ...  days_in_waiting_list  \
# 30874                     2       2       0.0  ...                     0
#
#          customer_type adr required_car_parking_spaces  \
# 30874  Transient-Party  42                           0
#
#       total_of_special_requests  reservation_status  reservation_status_date  \
# 30874                         0           Check-Out               2016-12-08
#
#        arrival_date addational_guests arrival_day
# 30874    2016-12-05                 0      Monday
#
# [1 rows x 33 columns]

# %%
Resort_Hotel.groupby('arrival_date_year')['reservation_status'].agg(["value_counts"])
# Out:
#                                       value_counts
# arrival_date_year reservation_status
# 2015              Check-Out                   6176
#                   Canceled                    2069
#                   No-Show                       69
# 2016              Check-Out                  13637
#                   Canceled                    4817
#                   No-Show                      113
# 2017              Check-Out                   9125
#                   Canceled                    3945
#                   No-Show                      109

# %%
ml = sns.countplot(data =Resort_Hotel , x= 'arrival_date_year', hue = "reservation_status" )
for m in ml.patches:
  ml.annotate((m.get_height()),(m.get_x() + 0.1,m.get_height()+500),fontsize=10)

# %% [markdown]
# ###<b>Observation:
# * As compair to city hotel the booking cancelation of resort hotel low.
# * resort hotel cancelation are low as comair to booking

# %% [markdown]
# ###<b>(M) which are the mostly reserved room types are  ?

# %%
data.groupby(["hotel"])["reserved_room_type"].agg(["value_counts"])
# Out:
#                                  value_counts
# hotel        reserved_room_type
# City Hotel   A                          62595
#              D                          11768
#              F                           1791
#              E                           1553
#              B                           1115
#              G                            484
#              C                             14
#              P                             10
# Resort Hotel A                          23399
#              D                           7433
#              E                           4982
#              G                           1610
#              F                           1106
#              C                            918
#              H                            601
#              L                              6
#              B                              3
#              P                              2

# %%
sns.countplot(x = "hotel", hue = "reserved_room_type", data = df)

# %% [markdown]
# ####<b>observation:
# * The "A" type room is most liked by people and then "D" type in both hotel.

# %% [markdown]
# ###<b>(N) How many visitors get room which they reserved?

# %%
total_resrved_room_type = df["reserved_room_type"].agg(["count"])
total_resrved_room_type
# Out:
# count    119390
# Name: reserved_room_type, dtype: int64

# %%
got_thair_room = df["reserved_room_type"][df["reserved_room_type"] ==  df["assigned_room_type"]].agg(["count"])
got_thair_room
# Out:
# count    104473
# Name: reserved_room_type, dtype: int64

# %% [markdown]
# ####<b>Observation:
# * Out of 119390 only 104473 visitors got their room which they reserved.

# %% [markdown]
# ###<b>(O)What is Deposit Type hotel-wise ?

# %%
types_of_deposite = df.groupby(["hotel"])["deposit_type"].value_counts().sort_index().to_frame()
types_of_deposite
# Out:
#                            deposit_type
# hotel        deposit_type
# City Hotel   No Deposit           66442
#              Non Refund           12868
#              Refundable              20
# Resort Hotel No Deposit           38199
#              Non Refund            1719
#              Refundable             142

# %% [markdown]
# ###<b> Which deposite type has more chance to cancel the booking ?

# %%
depodit_type_cancel = data["deposit_type"][data["is_canceled"] == 1].agg(['value_counts'])
print(depodit_type_cancel)
# Out:
#             value_counts
# No Deposit         29694
# Non Refund         14494
# Refundable            36

# %%
depodit_type_cancel.plot(kind='bar')

# %% [markdown]
# ####<b>Observation:
# * No Deposite customer type are more likely to cancel the booking more than the other types

# %% [markdown]
# ###<b>(P) How many Days in waiting list hotel-wise?

# %%
# numb = []
# for i in range (159):
#   numb.append(i)
# hotel_wating_list.insert(loc=0, column="ind", value=numb)

# %%
hotel_wating_list = (df.groupby(["hotel"])["days_in_waiting_list"].agg(["value_counts"]))
hotel_wating_list
# Out:
#                                    value_counts
# hotel        days_in_waiting_list
# City Hotel   0                            75887
#              39                             226
#              58                             164
#              44                             140
#              31                             127
# ...                                         ...
# Resort Hotel 93                               1
#              105                              1
#              109                              1
#              116                              1
#              142                              1
#
# [159 rows x 1 columns]

# %% [markdown]
# ##<b>(Q)Which type of customers are more likely to cancel the booking?

# %%
customer_types = df['customer_type'][df['is_canceled']==1].agg(['value_counts'])
customer_types
# Out:
#                  value_counts
# Transient               36514
# Transient-Party          6389
# Contract                 1262
# Group                      59

# %%
customer_types.plot(kind= 'bar')

# %% [markdown]
# ####<b>Observation:
# * Transient customer type are more likely to cancel the booking more than the other types

# %% [markdown]
# ###<b> (R) what is the average daily rate

# %%
hotel_adr = df.groupby("hotel")['adr'].agg(['sum'])
hotel_adr.rename(columns = {"sum":"average_daily_rate"}, inplace = True)
hotel_adr
# Out:
#               average_daily_rate
# hotel
# City Hotel               8337465
# Resort Hotel             3795754

# %%
hotel_adr.plot(kind = 'bar')

# %%
year_adr = df.groupby("arrival_date_year")['adr'].agg(['sum'])
year_adr.rename(columns = {"sum":"average_daily_rate"}, inplace = True)

year_adr
# Out:
#                    average_daily_rate
# arrival_date_year
# 2015                          1913628
# 2016                          5562899
# 2017                          4656692

# %%
year_adr.describe().plot(kind='bar')

# %% [markdown]
# ##<b>(S).Is the parking space is most required ?

# %%
parking_space = df.groupby('arrival_date_year')['required_car_parking_spaces'].sum().reset_index()
parking_space.head()
# Out:
#    arrival_date_year  required_car_parking_spaces
# 0               2015                         1352
# 1               2016                         3875
# 2               2017                         2237

# %%
plt.figure(figsize=(8,6))
sns.countplot(x = 'arrival_date_year' , data=df ,hue = "required_car_parking_spaces" )
# plt.title('Required Parking Spaces by Reservation')
plt.ylabel('no of booking')
plt.xlabel('years')
# Out:
# Text(0.5, 0, 'years')

# %% [markdown]
# ####<b>Observation:
# * around 90% of reservation do not require a parking space.

# %% [markdown]
# ###<b>(T) How many special requests received by each hotel?

# %%
special = data.groupby(["hotel"])["total_of_special_requests"].agg(["value_counts"])
special
# Out:
#                                         value_counts
# hotel        total_of_special_requests
# City Hotel   0                                 47957
#              1                                 21420
#              2                                  8142
#              3                                  1587
#              4                                   198
#              5                                    26
# Resort Hotel 0                                 22361
#              1                                 11806
#              2                                  4827
#              3                                   910
#              4                                   142
#              5                                    14

# %%
ml = sns.countplot(data = df , x='hotel' , hue='total_of_special_requests' )
for m in ml.patches:
  ml.annotate((m.get_height()),(m.get_x() + 0.1,m.get_height()+500),fontsize=10)

# %% [markdown]
# ###<b> cancelation of hotel for special request ?

# %%
splecial = data.groupby(["total_of_special_requests"])["is_canceled"].agg(["value_counts"])
splecial
# Out:
#                                        value_counts
# total_of_special_requests is_canceled
# 0                         0                   36762
#                           1                   33556
# 1                         0                   25908
#                           1                    7318
# 2                         0                   10103
#                           1                    2866
# 3                         0                    2051
#                           1                     446
# 4                         0                     304
#                           1                      36
# 5                         0                      38
#                           1                       2

# %%
ml = sns.countplot(data = df , hue='is_canceled' , x='total_of_special_requests' )
for m in ml.patches:
  ml.annotate((m.get_height()),(m.get_x() + 0.1,m.get_height()+500),fontsize=10)

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ###<b>SUMMERY:
# * City Hotel gets higher booking then Resort hotel and the cancelation rate is also higher of Resort Hotel.
# * Resort Hotels gets most high values customers.
# * In 2016 the booking ratio is more then 15% from all others years.
# * The City hotel has more guests during spring and autumn, when the prices are also highest, In July and August, there are fewer visitors, although prices are lower. (Thus, customers can get a good deal on bookings in July and August in a city hotel).
# * Guest numbers for the Resort hotel go down slightly from June to September, which is also when the prices are highest. (Thus, these months should be avoided for bookings).
# * Broadly, April to August is the peak season for bookings. Both hotels have the fewest guests during the winter.
# * Wekkend are more crouded then weekday
# * Online TA ,Groups are makes the most booking and cancellation of hotels as compair to other market segment catagory.
# *  A and D type room is more booked by user.
# *  A higher lead time has a higher chance of cancellation .
# *  A history of previous cancellations increases the chances of cancellation.

# %% [markdown]
# ###<b>RECOMMENDATION:
# * Resort hotels tend to have fewer bookings in comparison to city hotels so they need to work on their marketing strategy and promote the hotels more, especially on social media.
#  * Resort hotels could also reduce prices to increase booking percentages.
#  * Set Non-refundable Rates, Collect deposits, and implement more rigid cancellation policies.
#  * Encourage Direct bookings by offering special discounts
#  * May-August happens to be the busiest month, so the hotels should target more customers and try to do more business.
# * Although city hotels have more bookings, they also tend to have more cancellations so to prevent this they could take advance money during vacation. This would ensure most bookings to not canceled. They could also apply no-refund policies or make the refund policies rather strict so the customers choose not to cancel.
#  * Majority of the hotels booked are city hotels. Need to spend the most targeting fund on that hotel.
#   * We also realize that the high rate of cancellations can be due to high no deposit policies
# * It is quite clear most customers travel in pairs and bringing children or babies along is very rare so the hotels could advertise in ways that attract couples more and also business travelers.
# * Most guests do not return but as these customers have already visited once, advertisements should be targeted in such ways so they are bound to return the next time they visit. The customers could also be offered special benefits if they do return to stay.
# * Majority of the guests are from Western Europe. We should spend a significant amount of our budget on that area.

# %% [markdown]
# ###<B>Strategies to Counter High Cancellations at the Hotel:
#
# Hotel should charge some booking deposite for these tpe of people:
#
# 1. Crouded Months(Jul-Aug)
# 1.   Customers who have the lead time grater than 100 days or more then 100 days.
# 2.   Customers with previous cancellation
#     * Online TA
#     * Offline TA/TO
#     * country :- AGO , ARG
# 3.  Couple of Adult
#     * 3rd Weekend night
# 4.Larger group of booking
